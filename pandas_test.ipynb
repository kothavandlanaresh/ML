# %%
import pandas as pd
import numpy as np

# %%
arr=np.random.randint(1,100,(3,3))

df = pd.DataFrame(arr, columns=["A","B","C"], index = ["X","y","z"])

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.describe()
# Out:
#                A          B          C
# count   3.000000   3.000000   3.000000
# mean   55.000000  69.666667  39.666667
# std    33.778692  16.802778   8.962886
# min    16.000000  55.000000  34.000000
# 25%    45.000000  60.500000  34.500000
# 50%    74.000000  66.000000  35.000000
# 75%    74.500000  77.000000  42.500000
# max    75.000000  88.000000  50.000000

# %%
df
# Out:
#     A   B   C
# X  16  66  50
# y  74  88  34
# z  75  55  35

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].unique()
# Out:
# array([16, 74, 75])

# %%
df.shape
# Out:
# (3, 3)

# %%
df1=pd.read_csv('./Data/concrete.csv')

df1.head()
# Out:
#    cement   slag  ash  water  superplastic  coarseagg  fineagg  age  strength
# 0   540.0    0.0  0.0  162.0           2.5     1040.0    676.0   28     79.99
# 1   540.0    0.0  0.0  162.0           2.5     1055.0    676.0   28     61.89
# 2   332.5  142.5  0.0  228.0           0.0      932.0    594.0  270     40.27
# 3   332.5  142.5  0.0  228.0           0.0      932.0    594.0  365     41.05
# 4   198.6  132.4  0.0  192.0           0.0      978.4    825.5  360     44.30

# %%
df1.sample(10)
# Out:
#      cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 617   254.0    0.0    0.0  198.0           0.0      968.0    863.0    3
# 155   362.6  189.0    0.0  164.9          11.6      944.7    755.8   56
# 658   305.3  203.5    0.0  203.5           0.0      965.4    631.0    7
# 8     266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 329   246.8    0.0  125.1  143.3          12.0     1086.8    800.9    3
# 908   313.0  145.0    0.0  127.0           8.0     1000.0    822.0   28
# 898   336.0    0.0    0.0  182.0           3.0      986.0    817.0   28
# 351   213.5    0.0  174.2  154.6          11.7     1052.3    775.5   28
# 542   255.0    0.0    0.0  192.0           0.0      889.8    945.0   90
# 778   295.0    0.0    0.0  185.0           0.0     1069.0    769.0    7
#
#      strength
# 617      9.31
# 155     77.30
# 658     25.89
# 8       45.85
# 329     23.52
# 908     44.52
# 898     44.86
# 351     45.94
# 542     21.86
# 778     14.80

# %%
#df1.index = df1["slag"]

coffee=pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/warmup-data/coffee.csv')

coffee.head
# Out:
# <bound method NDFrame.head of           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35>

# %%
coffee.loc[1,"Units Sold"] = 10

coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.Day
print("\n\n")

coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee[coffee["Units Sold"] > 30]["Day"]
# Out:
# 4     Wednesday
# 6      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee[coffee["Coffee Type"].str.contains("Es")]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
olym_results = pd.read_csv('results.csv')

olym_results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
ind_oly_results_90= olym_results[(olym_results['noc'] == 'IND') & (olym_results['medal'].notna()) & (olym_results['year'] > 1990)]

print(ind_oly_results_90)
# Out:
#           year    type     discipline  \
# 815     1996.0  Summer         Tennis
# 198645  2008.0  Summer       Shooting
# 202806  2000.0  Summer  Weightlifting
# 226718  2012.0  Summer       Shooting
# 226776  2004.0  Summer       Shooting
# 229566  2008.0  Summer         Boxing
# 233672  2008.0  Summer      Wrestling
# 233673  2012.0  Summer      Wrestling
# 233751  2012.0  Summer      Wrestling
# 243511  2012.0  Summer      Badminton
# 260121  2010.0  Summer         Boxing
# 260146  2020.0  Summer         Hockey
# 260281  2020.0  Summer         Hockey
# 260290  2020.0  Summer         Hockey
# 263286  2010.0  Summer         Boxing
# 263310  2012.0  Summer         Boxing
# 267158  2012.0  Summer       Shooting
# 279130  2016.0  Summer      Badminton
# 279131  2020.0  Summer      Badminton
# 279177  2020.0  Summer  Weightlifting
# 279179  2016.0  Summer      Wrestling
# 285340  2020.0  Summer         Hockey
# 285342  2020.0  Summer         Hockey
# ...

# %%
ind_oly_results_90[ind_oly_results_90['year'] < 2000].sort_values(by='discipline').head(40)
# Out:
#        year    type discipline                   event            as  \
# 815  1996.0  Summer     Tennis  Singles, Men (Olympic)  Leander Paes
#
#      athlete_id  noc team  place   tied   medal
# 815         287  IND  NaN    3.0  False  Bronze

# %%
ind_oly_results_90.query('noc == "IND" and medal.notna()').head()
# Out:
#           year    type     discipline                                event  \
# 815     1996.0  Summer         Tennis               Singles, Men (Olympic)
# 198645  2008.0  Summer       Shooting  Air Rifle, 10 metres, Men (Olympic)
# 202806  2000.0  Summer  Weightlifting   Light-Heavyweight, Women (Olympic)
# 226718  2012.0  Summer       Shooting  Air Rifle, 10 metres, Men (Olympic)
# 226776  2004.0  Summer       Shooting           Double Trap, Men (Olympic)
#
#                           as  athlete_id  noc team  place   tied   medal
# 815             Leander Paes         287  IND  NaN    3.0  False  Bronze
# 198645        Abhinav Bindra       93075  IND  NaN    1.0  False    Gold
# 202806     Karnam Malleswari       94934  IND  NaN    3.0  False  Bronze
# 226718          Gagan Narang      104771  IND  NaN    3.0  False  Bronze
# 226776  Rajyavardhan Rathore      104792  IND  NaN    2.0  False  Silver

# %%
coffee

# %%
coffee=pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/warmup-data/coffee.csv')

coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35
